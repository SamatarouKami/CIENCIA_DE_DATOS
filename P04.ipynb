# %% [markdown]
# # Reporte de práctica 4: Visualización de información con plotly
#
# Plotly, también conocida por su URL, [Plot.ly](https://plot.ly/),es una empresa de computación técnica con sede en Montreal, Quebec, que desarrolla herramientas de visualización y análisis de datos en línea. Plotly proporciona herramientas de gráficos, análisis y estadísticas en línea para individuos y colaboración, así como bibliotecas de gráficos científicos para Python, R, MATLAB, Perl, Julia, Arduino y REST.
#
# ## Objetivos
#
#     -Incluir al menos tres diferentes tipos de gráficas usando plotly e intenter concluir algo sobre los datos.
#
# ## Los datos
#
# Debido a que la base de datos con la que contamos se encuentra fragmentada en años, utilizaremos la que cuente con la información más completa.
#
# ### Importando datos

# %%
import pandas as pd
df2018 = pd.read_excel('2018.xlsx', index_col=None, header=0, sheet_name=0)
df2018 = df2018[['Categoria','Edad','Pais', 'Titulo','Genero', 'Duracion', 'Marca','Referencia','Dias','Marcas','Personas']]
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-26e5a7ea64ff> in <module>()
#       1 import pandas as pd
# ----> 2 df2018 = pd.read_excel('2018.xlsx', index_col=None, header=0, sheet_name=0)
#       3 df2018 = df2018[['Categoria','Edad','Pais', 'Titulo','Genero', 'Duracion', 'Marca','Referencia','Dias','Marcas','Personas']]
#
# /home/samataroukami/.local/lib/python2.7/site-packages/pandas/util/_decorators.pyc in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# --> 188             return func(*args, **kwargs)
#     189         return wrapper
#     190     return _deprecate_kwarg
#
# /home/samataroukami/.local/lib/python2.7/site-packages/pandas/util/_decorators.pyc in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# --> 188             return func(*args, **kwargs)
#     189         return wrapper
#     190     return _deprecate_kwarg
#
# /home/samataroukami/.local/lib/python2.7/site-packages/pandas/io/excel.pyc in read_excel(io, sheet_name, header, names, index_col, parse_cols, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skip_footer, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     348
#     349     if not isinstance(io, ExcelFile):
# --> 350         io = ExcelFile(io, engine=engine)
#     351
#     352     return io.parse(
#
# /home/samataroukami/.local/lib/python2.7/site-packages/pandas/io/excel.pyc in __init__(self, io, engine)
#     651         self._io = _stringify_path(io)
#     652
# --> 653         self._reader = self._engines[engine](self._io)
#     654
#     655     def __fspath__(self):
#
# /home/samataroukami/.local/lib/python2.7/site-packages/pandas/io/excel.pyc in __init__(self, filepath_or_buffer)
#     391             import xlrd
#     392         except ImportError:
# --> 393             raise ImportError(err_msg)
#     394         else:
#     395             if xlrd.__VERSION__ < LooseVersion("1.0.0"):
#
# ImportError: Install xlrd >= 1.0.0 for Excel support
